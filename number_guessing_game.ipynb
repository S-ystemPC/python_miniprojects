# %% [markdown]
# # Intution

# %%
# generate a random number
# Asking user to guess
# if not a valid number 
# print an error
# if number < guess
# print too low
# if number > guess
# print too high
# else
# print guessed correct
