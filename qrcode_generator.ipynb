# %% [markdown]
# # Intution

# %%
# created venv -- [python -m venv venv]
# activated venv -- [venv\Scripts\activate]
# installed library -- [pip install qrcode]
# intalled jupyter notebook inside venv -- [pip install notebook]
# run notebook -- [jupyter notebook]
# navigate to the ipynb file -- [in this case qrcode_generator]
# import the library -- [import qrcode]

# %%
import qrcode

data = input('Enter the text or URL: ').strip()
filename = input('Enter the filename: ').strip()
qr = qrcode.QRCode(box_size=10, border=4)
qr.add_data(data)
image = qr.make_image(fill_color='black', back_color='white')
image.save(filename)
print(f'QR Code saved as {filename}')
# Out:
# Enter the text or URL:  https://codewithpc.com
# Enter the filename:  pc.jpg
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       3 data = input('Enter the text or URL: ').strip()
#       4 filename = input('Enter the filename: ').strip()
#       5 qr = qrcode.QRCode(box_size=10, border=4)
#       6 qr.add_data(data)
# ----> 7 image = qr.make_image(fill_color='black', back_color='white')
#       8 image.save(filename)
#       9 print(f'QR Code saved as {filename}')
#
# File E:\python_mini_projects\venv\Lib\site-packages\qrcode\main.py:364, in QRCode.make_image(self, image_factory, **kwargs)
#     362 image_factory = self.image_factory
#     363 if image_factory is None:
# --> 364     from qrcode.image.pil import Image, PilImage
#     366     # Use PIL by default if available, otherwise use PyPNG.
# ...
